# %% [markdown]
# # Evolução do semieixo maior dos planetas do Sistema Solar
# Foi realizada simulação a partir da data 01/01/2000 às 00h00min00s (JD 2451544.5), num intervalo de tempo de 100 milhões de anos.
#
# São plotados os semieixo maior com os respectivos apoastro e periastro.

# %% [markdown]
# ## Importando módulos

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import os

# %% [markdown]
# ## Configurando a função para plotar os gráficos

# %%
font = {'family' : 'sans-serif',
        'style'  : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
def plot_figure(planets, variable, variable2, title, ylabel, xmin = 0, xmax = 1e8):
#     plt.figure(figsize = (14, 8))
#     for planet, variable in zip(planets, variables):
#         plt.plot(time, variable, label = planet)
#     plt.title(title)
#     plt.xlabel("t [yr]")
#     plt.ylabel(ylabel)
#     plt.xlim(xmin,xmax)
#     plt.legend(loc = 1)
#     plt.grid()
#     plt.show()
    
    plt.figure(figsize = (14, 8))
    for planet, variable in zip(planets, variables):
        plt.plot(time, variable, label = planet)
    for variable2 in variables2:
        plt.plot(time, variable2, label = "_nolegend_", color = "black", linewidth=0.5)
    plt.title(title)
    plt.xlabel("t [yr]")
    plt.ylabel(ylabel)
    plt.xlim(xmin,xmax)
    plt.legend(loc = 1)
    plt.grid()
    plt.show()

# %% [markdown]
# ## Lendo arquivos de dados
#
# Lendo os dados a partir dos arquivos convertidos pelo notebook "Converter_binario_ascii.ipynb"

# %%
# change work directory
os.chdir("SolarSystem_mvs-001/")

# %%
cabecalho = ["t","a","e","inc","capom","omega","capm","peri","apo","obar"]

# %%
# Create planets' dataframes
mercury = pd.read_fwf("mercury.out", names = cabecalho)
venus = pd.read_fwf("venus.out", names = cabecalho)
earth = pd.read_fwf("earth.out", names = cabecalho)
mars = pd.read_fwf("mars.out", names = cabecalho)
jupiter = pd.read_fwf("jupiter.out", names = cabecalho)
saturn = pd.read_fwf("saturn.out", names = cabecalho)
uranus = pd.read_fwf("uranus.out", names = cabecalho)
neptune = pd.read_fwf("neptune.out", names = cabecalho)

time = jupiter.t

# %% [markdown]
# ## Planetas gigantes: 100 000 000 anos

# %%
title = "Semi-major axis of the giant planets in $10^8$ years"
planets = ["Jupiter", "Saturn", "Uranus", "Neptune"]
variables = [jupiter["a"], saturn["a"], uranus["a"], neptune["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 1e8
ylabel = "a [au]"

plot_figure(planets, variables, variable2, title, ylabel, xmin, xmax)

# %% [markdown]
# ## Planetas gigantes: 10 000 000 anos

# %%
title = "Semi-major axis of the giant planets in $10^7$ years"
planets = ["Jupiter", "Saturn", "Uranus", "Neptune"]
variables = [jupiter["a"], saturn["a"], uranus["a"], neptune["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 1e7
ylabel = "a [au]"

plot_figure(planets, variables, variable2, title, ylabel, xmin, xmax)

# %% [markdown]
# ## Planetas gigantes: 400 000 anos

# %%
title = "Semi-major axis of the giant planets in 400 000 years"
planets = ["Jupiter", "Saturn", "Uranus", "Neptune"]
variables = [jupiter["a"], saturn["a"], uranus["a"], neptune["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 4e5
ylabel = "a [au]"

plot_figure(planets, variables, variable2, title, ylabel, xmin, xmax)

# %% [markdown]
# ## Planetas internos: 100 000 000 anos

# %%
title = "Semi-major axis of the inner planets in $10^8$ years"
planets = ["Mercury", "Venus", "Earth", "Mars"]
variables = [mercury["a"], venus["a"], earth["a"], mars["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 1e8
ylabel = "a [au]"

plot_figure(planets, variables, variable2, title, ylabel, xmin, xmax)

# %% [markdown]
# ## Planetas internos: 10 000 000 anos

# %%
title = "Semi-major axis of the inner planets in $10^7$ years"
planets = ["Mercury", "Venus", "Earth", "Mars"]
variables = [mercury["a"], venus["a"], earth["a"], mars["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 1e7
ylabel = "a [au]"

plot_figure(planets, variables, variable2, title, ylabel, xmin, xmax)

# %% [markdown]
# ## Planetas internos: 400 000 anos

# %%
title = "Semi-major axis of the inner planets in 400 000 years"
planets = ["Mercury", "Venus", "Earth", "Mars"]
variables = [mercury["a"], venus["a"], earth["a"], mars["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 4e5
ylabel = "a [au]"

plot_figure(planets, variables2, title, ylabel, xmin, xmax)

# %%
title = "Semi-major axis of the inner planets in 400 000 years"
planets = ["Mercury", "Venus", "Earth", "Mars"]
variables = [mercury["a"], venus["a"], earth["a"], mars["a"]]
variables2 = [mercury["apo"],mercury["peri"], venus["apo"],venus["peri"],\
              earth["apo"],earth["peri"], mars["apo"],mars["peri"]]
xmin = 0
xmax = 1e5
ylabel = "a [au]"

plot_figure(planets, variable, variable2, title, ylabel, xmin, xmax)

# %%
os.chdir("../")
